# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df_res = pd.read_csv('df_results_skincancer_new_interpretability.csv', index_col=0)
df_res = df_res.round(3)
df_res
# Out:
#               dice_score_ig  iou_score_ig  dice_score_saliency  \
# ISIC_0016028          0.040         0.020                0.040
# ISIC_0014944          0.933         0.874                0.221
# ISIC_0015990          0.429         0.273                0.468
# ISIC_0016057          0.085         0.044                0.085
# ISIC_0015089          0.723         0.566                0.513
# ...                     ...           ...                  ...
# ISIC_0015215          0.304         0.180                0.304
# ISIC_0015142          0.680         0.516                0.681
# ISIC_0016015          0.131         0.070                0.131
# ISIC_0012722          0.026         0.013                0.026
# ISIC_0013814          0.808         0.678                0.808
#
#               iou_score_saliency  dice_score_deep_lift  iou_score_deep_lift  \
# ISIC_0016028               0.020                 0.040                0.020
# ...

# %%
df_res.columns
# Out:
# Index(['dice_score_ig', 'iou_score_ig', 'dice_score_saliency',
#        'iou_score_saliency', 'dice_score_deep_lift', 'iou_score_deep_lift',
#        'dice_score_grad_cam', 'iou_score_grad_cam', 'label_ground_truth',
#        'label_predicted'],
#       dtype='object')

# %%
df_res[['dice_score_ig', 'dice_score_saliency', 'dice_score_deep_lift', 'dice_score_grad_cam']].describe()
# Out:
#        dice_score_ig  dice_score_saliency  dice_score_deep_lift  \
# count     600.000000           600.000000            600.000000
# mean        0.370333             0.355475              0.370333
# std         0.274045             0.277165              0.274045
# min         0.000000             0.000000              0.000000
# 25%         0.116500             0.098000              0.116500
# 50%         0.320000             0.291500              0.320000
# 75%         0.578500             0.573250              0.578500
# max         0.994000             0.994000              0.994000
#
#        dice_score_grad_cam
# count           600.000000
# mean              0.370333
# std               0.274045
# min               0.000000
# 25%               0.116500
# 50%               0.320000
# 75%               0.578500
# max               0.994000

# %%
df_res[['iou_score_ig', 'iou_score_saliency','iou_score_deep_lift', 'iou_score_grad_cam']].describe()
# Out:
#        iou_score_ig  iou_score_saliency  iou_score_deep_lift  \
# count    600.000000          600.000000           600.000000
# mean       0.267385            0.256660             0.267385
# std        0.242904            0.244344             0.242904
# min        0.000000            0.000000             0.000000
# 25%        0.061750            0.051750             0.061750
# 50%        0.191000            0.171000             0.191000
# 75%        0.407500            0.402250             0.407500
# max        0.988000            0.989000             0.988000
#
#        iou_score_grad_cam
# count          600.000000
# mean             0.267385
# std              0.242904
# min              0.000000
# 25%              0.061750
# 50%              0.191000
# 75%              0.407500
# max              0.988000

# %%
df_res.columns
# Out:
# Index(['dice_score_ig', 'iou_score_ig', 'dice_score_saliency',
#        'iou_score_saliency', 'dice_score_deep_lift', 'iou_score_deep_lift',
#        'dice_score_grad_cam', 'iou_score_grad_cam', 'label_ground_truth',
#        'label_predicted'],
#       dtype='object')

# %%
fig = px.violin(df_res[['dice_score_ig', 'dice_score_saliency', 'dice_score_deep_lift', 'dice_score_grad_cam']], points="all", color_discrete_sequence=['darkblue'], title='Dice scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='Dice Score')
fig.write_html('dice_score_distribution_interpretabilities.html')
fig.write_image('dice_score_distribution_interpretabilities.png')
fig.show()

# %%
fig = px.violin(df_res[['iou_score_ig', 'iou_score_saliency','iou_score_deep_lift', 'iou_score_grad_cam']], points="all", color_discrete_sequence=['green'], title='IoU scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='IoU score')
fig.show()
fig.write_html('iou_distribution_interpretabilities.html')
fig.write_image('iou_distribution_interpretabilities.png')

# %%
df_res.columns
# Out:
# Index(['dice_score_ig', 'iou_score_ig', 'dice_score_saliency',
#        'iou_score_saliency', 'dice_score_deep_lift', 'iou_score_deep_lift',
#        'dice_score_grad_cam', 'iou_score_grad_cam', 'label_ground_truth',
#        'label_predicted'],
#       dtype='object')

# %%
df_res_giuste = df_res[df_res['label_ground_truth'] == df_res['label_predicted']]
df_res_giuste
# Out:
#               dice_score_ig  iou_score_ig  dice_score_saliency  \
# ISIC_0016028          0.040         0.020                0.040
# ISIC_0014944          0.933         0.874                0.221
# ISIC_0015990          0.429         0.273                0.468
# ISIC_0016057          0.085         0.044                0.085
# ISIC_0015089          0.723         0.566                0.513
# ...                     ...           ...                  ...
# ISIC_0016034          0.055         0.028                0.057
# ISIC_0015368          0.932         0.872                0.930
# ISIC_0015215          0.304         0.180                0.304
# ISIC_0016015          0.131         0.070                0.131
# ISIC_0012722          0.026         0.013                0.026
#
#               iou_score_saliency  dice_score_deep_lift  iou_score_deep_lift  \
# ISIC_0016028               0.020                 0.040                0.020
# ...

# %%
df_res_giuste[['dice_score_ig', 'dice_score_saliency', 'dice_score_deep_lift', 'dice_score_grad_cam']].describe()
# Out:
#        dice_score_ig  dice_score_saliency  dice_score_deep_lift  \
# count     403.000000           403.000000            403.000000
# mean        0.358025             0.343154              0.358025
# std         0.275421             0.279878              0.275421
# min         0.000000             0.007000              0.000000
# 25%         0.106000             0.089500              0.106000
# 50%         0.291000             0.266000              0.291000
# 75%         0.559500             0.545000              0.559500
# max         0.994000             0.994000              0.994000
#
#        dice_score_grad_cam
# count           403.000000
# mean              0.358025
# std               0.275421
# min               0.000000
# 25%               0.106000
# 50%               0.291000
# 75%               0.559500
# max               0.994000

# %%
df_res_giuste[['iou_score_ig', 'iou_score_saliency','iou_score_deep_lift', 'iou_score_grad_cam']].describe()
# Out:
#        iou_score_ig  iou_score_saliency  iou_score_deep_lift  \
# count    403.000000          403.000000           403.000000
# mean       0.258357            0.248000             0.258357
# std        0.244755            0.246282             0.244755
# min        0.000000            0.003000             0.000000
# 25%        0.055500            0.046500             0.055500
# 50%        0.171000            0.154000             0.171000
# 75%        0.388500            0.374500             0.388500
# max        0.988000            0.989000             0.988000
#
#        iou_score_grad_cam
# count          403.000000
# mean             0.258357
# std              0.244755
# min              0.000000
# 25%              0.055500
# 50%              0.171000
# 75%              0.388500
# max              0.988000

# %%
fig = px.violin(df_res_giuste[['dice_score_ig', 'dice_score_saliency', 'dice_score_deep_lift', 'dice_score_grad_cam']], points="all", color_discrete_sequence=['darkblue'], title='Dice scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='Dice Score')
fig.write_html('dice_score_distribution_interpretabilities_giuste.html')
fig.write_image('dice_score_distribution_interpretabilities_giuste.png')
fig.show()

# %%
fig = px.violin(df_res_giuste[['iou_score_ig', 'iou_score_saliency','iou_score_deep_lift', 'iou_score_grad_cam']], points="all", color_discrete_sequence=['green'], title='IoU scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='IoU score')
fig.show()
fig.write_html('iou_distribution_interpretabilities_giuste.html')
fig.write_image('iou_distribution_interpretabilities_giuste.png')
