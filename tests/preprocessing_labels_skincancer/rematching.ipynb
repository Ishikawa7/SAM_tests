# %%
import pandas as pd
import os

# %%
df_train_gt_binary = pd.read_csv('ISIC_2020_Training_GroundTruth_v2.csv')
df_train_gt_binary
# Out:
#          image_name  patient_id   lesion_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968  IL_7972535    male        45.0
# 1      ISIC_0015719  IP_3075186  IL_4649854  female        45.0
# 2      ISIC_0052212  IP_2842074  IL_9087444  female        50.0
# 3      ISIC_0068279  IP_6890425  IL_4255399  female        45.0
# 4      ISIC_0074268  IP_8723313  IL_6898037  female        55.0
# ...             ...         ...         ...     ...         ...
# 33121  ISIC_9999134  IP_6526534  IL_2076932    male        50.0
# 33122  ISIC_9999320  IP_3650745  IL_6891604    male        65.0
# 33123  ISIC_9999515  IP_2026598  IL_6364820    male        20.0
# 33124  ISIC_9999666  IP_7702038  IL_6048457    male        50.0
# 33125  ISIC_9999806  IP_0046310  IL_5788213    male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target
# 0                         head/neck   unknown           benign       0
# ...

# %%
df_train_gt = pd.read_csv('train_GroundTruth2.csv')
df_train_gt
# Out:
#           image_id  melanoma  seborrheic_keratosis  none
# 0     ISIC_0000000       0.0                   0.0   1.0
# 1     ISIC_0000001       0.0                   0.0   1.0
# 2     ISIC_0000002       1.0                   0.0   0.0
# 3     ISIC_0000003       0.0                   0.0   1.0
# 4     ISIC_0000004       1.0                   0.0   0.0
# ...            ...       ...                   ...   ...
# 1995  ISIC_0015220       0.0                   1.0   0.0
# 1996  ISIC_0015233       0.0                   1.0   0.0
# 1997  ISIC_0015260       0.0                   1.0   0.0
# 1998  ISIC_0015284       1.0                   0.0   0.0
# 1999  ISIC_0015295       0.0                   1.0   0.0
#
# [2000 rows x 4 columns]

# %%
df_train_gt["benign_malignant"] = df_train_gt_binary["benign_malignant"]
df_train_gt
# Out:
#           image_id  melanoma  seborrheic_keratosis  none benign_malignant
# 0     ISIC_0000000       0.0                   0.0   1.0           benign
# 1     ISIC_0000001       0.0                   0.0   1.0           benign
# 2     ISIC_0000002       1.0                   0.0   0.0           benign
# 3     ISIC_0000003       0.0                   0.0   1.0           benign
# 4     ISIC_0000004       1.0                   0.0   0.0           benign
# ...            ...       ...                   ...   ...              ...
# 1995  ISIC_0015220       0.0                   1.0   0.0           benign
# 1996  ISIC_0015233       0.0                   1.0   0.0           benign
# 1997  ISIC_0015260       0.0                   1.0   0.0           benign
# 1998  ISIC_0015284       1.0                   0.0   0.0           benign
# 1999  ISIC_0015295       0.0                   1.0   0.0           benign
#
# [2000 rows x 5 columns]

# %%
df_train_gt['benign_malignant'].value_counts()
# Out:
# benign_malignant
# benign       1970
# malignant      30
# Name: count, dtype: int64

# %%
classes = [
    'actinic keratosis', 'melanoma', 'seborrheic keratosis',
    'basal cell carcinoma', 'nevus', 'squamous cell carcinoma',
    'dermatofibroma', 'pigmented benign keratosis', 'vascular lesion'
]

# %%
folder = "images_classes"

# %%
# create a dataframe in which each row is an image, one column is the image id (corresponding to the image filename) and the other columns are the classes corresponding to the image folder
dict_df = {
    'image_id': [],
    'class': []
}
for c in classes:
    for image in os.listdir(os.path.join(folder, c)):
        dict_df['image_id'].append(image.split('.')[0])
        dict_df['class'].append(c)
df = pd.DataFrame(dict_df)
df
# Out:
#           image_id              class
# 0     ISIC_0030143  actinic keratosis
# 1     ISIC_0032422  actinic keratosis
# 2     ISIC_0029309  actinic keratosis
# 3     ISIC_0031430  actinic keratosis
# 4     ISIC_0026575  actinic keratosis
# ...            ...                ...
# 2358  ISIC_0030722    vascular lesion
# 2359  ISIC_0025250    vascular lesion
# 2360  ISIC_0031276    vascular lesion
# 2361  ISIC_0032839    vascular lesion
# 2362  ISIC_0028163    vascular lesion
#
# [2363 rows x 2 columns]

# %%
df_train_gt
# Out:
#           image_id  melanoma  seborrheic_keratosis  none benign_malignant
# 0     ISIC_0000000       0.0                   0.0   1.0           benign
# 1     ISIC_0000001       0.0                   0.0   1.0           benign
# 2     ISIC_0000002       1.0                   0.0   0.0           benign
# 3     ISIC_0000003       0.0                   0.0   1.0           benign
# 4     ISIC_0000004       1.0                   0.0   0.0           benign
# ...            ...       ...                   ...   ...              ...
# 1995  ISIC_0015220       0.0                   1.0   0.0           benign
# 1996  ISIC_0015233       0.0                   1.0   0.0           benign
# 1997  ISIC_0015260       0.0                   1.0   0.0           benign
# 1998  ISIC_0015284       1.0                   0.0   0.0           benign
# 1999  ISIC_0015295       0.0                   1.0   0.0           benign
#
# [2000 rows x 5 columns]

# %%
# Out:
#          image_id  melanoma  seborrheic_keratosis  none benign_malignant  \
# 0    ISIC_0000000       0.0                   0.0   1.0           benign
# 1    ISIC_0000001       0.0                   0.0   1.0           benign
# 2    ISIC_0000002       1.0                   0.0   0.0           benign
# 3    ISIC_0000003       0.0                   0.0   1.0           benign
# 4    ISIC_0000004       1.0                   0.0   0.0           benign
# ..            ...       ...                   ...   ...              ...
# 459  ISIC_0011166       1.0                   0.0   0.0           benign
# 460  ISIC_0011169       1.0                   0.0   0.0           benign
# 461  ISIC_0011169       1.0                   0.0   0.0           benign
# 462  ISIC_0011176       1.0                   0.0   0.0           benign
# 463  ISIC_0011176       1.0                   0.0   0.0           benign
#
#                     class
# 0                   nevus
# 1                   nevus
# ...
