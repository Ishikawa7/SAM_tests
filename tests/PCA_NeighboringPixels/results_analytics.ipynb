# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df_res = pd.read_csv('pca_nb_results.csv')
df_res = df_res.round(3)
df_res
# Out:
#              Image  Dice PCA1  IoU PCA1  Dice PCA2  IoU PCA2  Dice PCA3  \
# 0     ISIC_0010093      0.775     0.633      0.775     0.633      0.775
# 1     ISIC_0010201      0.836     0.719      0.837     0.719      0.836
# 2     ISIC_0014929      0.104     0.055      0.104     0.055      0.104
# 3     ISIC_0008992      0.010     0.005      0.012     0.006      0.013
# 4     ISIC_0012671      0.232     0.132      0.232     0.131      0.232
# ...            ...        ...       ...        ...       ...        ...
# 1995  ISIC_0010498      0.418     0.264      0.418     0.264      0.418
# 1996  ISIC_0010479      0.967     0.935      0.967     0.935      0.967
# 1997  ISIC_0013783      0.524     0.355      0.524     0.355      0.524
# 1998  ISIC_0000364      0.638     0.468      0.638     0.469      0.638
# 1999  ISIC_0012828      0.338     0.203      0.338     0.203      0.338
#
#       IoU PCA3  Dice PCA4  IoU PCA4  Dice PCA5  IoU PCA5
# 0        0.633      0.775     0.633      0.775     0.633
# 1        0.718      0.837     0.720      0.838     0.721
# 2        0.055      0.104     0.055      0.104     0.055
# 3        0.006      0.004     0.002      0.009     0.005
# 4        0.131      0.315     0.187      0.232     0.131
# ...        ...        ...       ...        ...       ...
# 1995     0.264      0.418     0.264      0.418     0.264
# 1996     0.935      0.967     0.936      0.967     0.935
# 1997     0.355      0.524     0.355      0.524     0.355
# 1998     0.468      0.638     0.468      0.638     0.468
# 1999     0.203      0.338     0.203      0.338     0.203
#
# [2000 rows x 11 columns]

# %%
df_res[['Dice PCA1', 'Dice PCA2', 'Dice PCA3', 'Dice PCA4', 'Dice PCA5']].describe()
# Out:
#          Dice PCA1    Dice PCA2    Dice PCA3    Dice PCA4    Dice PCA5
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.354548     0.353227     0.355697     0.355106     0.356770
# std       0.274773     0.271538     0.272430     0.272253     0.271366
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.116000     0.119000     0.120750     0.119000     0.121000
# 50%       0.287000     0.289000     0.291000     0.287000     0.291500
# 75%       0.552000     0.544500     0.552250     0.552250     0.553250
# max       0.989000     0.988000     0.988000     0.988000     0.988000

# %%
df_res[['IoU PCA1', 'IoU PCA2','IoU PCA3', 'IoU PCA4', 'IoU PCA5']].describe()
# Out:
#           IoU PCA1     IoU PCA2     IoU PCA3     IoU PCA4     IoU PCA5
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.256046     0.254021     0.256149     0.255653     0.256719
# std       0.246815     0.243559     0.244234     0.244052     0.243590
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.061750     0.063000     0.064000     0.063000     0.064000
# 50%       0.167500     0.169000     0.170000     0.167500     0.170500
# 75%       0.381000     0.373750     0.381500     0.381250     0.383000
# max       0.977000     0.976000     0.977000     0.977000     0.977000

# %%
df_res.columns
# Out:
# Index(['Image', 'Dice PCA1', 'IoU PCA1', 'Dice PCA2', 'IoU PCA2', 'Dice PCA3',
#        'IoU PCA3', 'Dice PCA4', 'IoU PCA4', 'Dice PCA5', 'IoU PCA5'],
#       dtype='object')

# %%
fig = px.violin(df_res[['Dice PCA1', 'Dice PCA2', 'Dice PCA3', 'Dice PCA4', 'Dice PCA5']], points="all", color_discrete_sequence=['darkblue'], title='IOU distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='IOU')
fig.show()

# %%
fig = px.violin(df_res[['IoU PCA1', 'IoU PCA2','IoU PCA3', 'IoU PCA4', 'IoU PCA5']], points="all", color_discrete_sequence=['green'], title='Dice scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='Dice score')
fig.show()
#fig.write_html('iou_distribution.html')

# %%
fig = px.violin(df_res[['Dice PCA1', 'IoU PCA1']], points="all", color_discrete_sequence=['green'], title='Scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='Score')
fig.show()
fig.write_html('res_pca_nb_scores.html')
