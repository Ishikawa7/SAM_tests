# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df_res = pd.read_csv('pca_nb_results.csv')
df_res = df_res.round(3)
df_res
# Out:
#             Image  Dice PCA1  IoU PCA1  Dice PCA2  IoU PCA2  Dice PCA3  \
# 0    ISIC_0016028      0.040     0.020      0.040     0.020      0.040
# 1    ISIC_0014944      0.933     0.874      0.932     0.873      0.933
# 2    ISIC_0015990      0.429     0.273      0.428     0.273      0.437
# 3    ISIC_0016057      0.085     0.044      0.085     0.044      0.085
# 4    ISIC_0015089      0.723     0.566      0.647     0.479      0.723
# ..            ...        ...       ...        ...       ...        ...
# 595  ISIC_0015215      0.304     0.180      0.304     0.180      0.304
# 596  ISIC_0015142      0.680     0.516      0.680     0.516      0.680
# 597  ISIC_0016015      0.131     0.070      0.131     0.070      0.131
# 598  ISIC_0012722      0.026     0.013      0.026     0.013      0.026
# 599  ISIC_0013814      0.808     0.678      0.808     0.678      0.808
#
#      IoU PCA3  Dice PCA4  IoU PCA4  Dice PCA5  IoU PCA5
# 0       0.020      0.040     0.020      0.040     0.020
# ...

# %%
df_res[['Dice PCA1', 'Dice PCA2', 'Dice PCA3', 'Dice PCA4', 'Dice PCA5']].describe()
# Out:
#         Dice PCA1   Dice PCA2   Dice PCA3   Dice PCA4   Dice PCA5
# count  600.000000  600.000000  600.000000  600.000000  600.000000
# mean     0.371855    0.371055    0.369087    0.367962    0.371287
# std      0.272827    0.267978    0.270080    0.268683    0.269183
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.123500    0.127500    0.123500    0.124750    0.125000
# 50%      0.320500    0.328500    0.326000    0.322500    0.328500
# 75%      0.580000    0.578500    0.574500    0.572250    0.576500
# max      0.994000    0.994000    0.994000    0.994000    0.994000

# %%
df_res[['IoU PCA1', 'IoU PCA2','IoU PCA3', 'IoU PCA4', 'IoU PCA5']].describe()
# Out:
#          IoU PCA1    IoU PCA2    IoU PCA3    IoU PCA4    IoU PCA5
# count  600.000000  600.000000  600.000000  600.000000  600.000000
# mean     0.268227    0.265993    0.265092    0.263970    0.266668
# std      0.241828    0.236297    0.238296    0.237976    0.238273
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.065750    0.067750    0.065750    0.066750    0.067000
# 50%      0.191000    0.196500    0.195000    0.192000    0.196500
# 75%      0.409000    0.406500    0.403250    0.401250    0.404500
# max      0.988000    0.988000    0.988000    0.988000    0.988000

# %%
df_res.columns
# Out:
# Index(['Image', 'Dice PCA1', 'IoU PCA1', 'Dice PCA2', 'IoU PCA2', 'Dice PCA3',
#        'IoU PCA3', 'Dice PCA4', 'IoU PCA4', 'Dice PCA5', 'IoU PCA5'],
#       dtype='object')

# %%
fig = px.violin(df_res[['Dice PCA1', 'Dice PCA2', 'Dice PCA3', 'Dice PCA4', 'Dice PCA5']], points="all", color_discrete_sequence=['darkblue'], title='Dice score distributions', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='IOU')
fig.write_html('dice_scores_distribution_pca_nb_skincancer_new.html')
fig.write_image('dice_scores_distribution_pca_nb_skincancer_new.png')
fig.show()

# %%
fig = px.violin(df_res[['IoU PCA1', 'IoU PCA2','IoU PCA3', 'IoU PCA4', 'IoU PCA5']], points="all", color_discrete_sequence=['green'], title='IoU scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='IoU score')
fig.show()
fig.write_html('iou_distribution_pca_nb_skincancer_new.html')
fig.write_image('iou_distribution_pca_nb_skincancer_new.png')

# %%
fig = px.violin(df_res[['Dice PCA1', 'IoU PCA1']], points="all", color_discrete_sequence=['green'], title='Scores distribution', box=True, width=1400, height=700)
fig.update_layout(xaxis_title='Model', yaxis_title='Score')
fig.show()
fig.write_html('res_pca_nb_scores.html')
fig.write_image('res_pca_nb_scores.png')
